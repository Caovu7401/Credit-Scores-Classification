# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

from scipy.stats import chi2_contingency, spearmanr, skew, pearsonr, zscore
from sklearn.utils import Bunch
from sklearn.feature_selection import mutual_info_classif
from sklearn.metrics import r2_score, roc_curve, auc, confusion_matrix, accuracy_score, classification_report, precision_recall_fscore_support, roc_auc_score
from sklearn.model_selection import train_test_split, cross_val_score, KFold, StratifiedKFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler, PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE
from sklearn.svm import SVC

#Random Forest
from sklearn.ensemble import RandomForestClassifier
#XGBOOST
import xgboost as xgb
from xgboost import XGBClassifier

# %%
data = pd.read_csv('D:/Python_Code/Bank Model/38.Credit Score Classification/Credit_score_cleaned_data.csv')
data
# Out:
#       Customer_ID  Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0      CUS_0x98ed   31  Journalist      22229.060            1672.421667
# 1      CUS_0x36b4   43    Musician      17060.705            1685.725417
# 2      CUS_0x105b   24  Accountant      34428.210            2575.017500
# 3      CUS_0x4c4a   21  Accountant      12613.920            1155.160000
# 4      CUS_0x612f   31  Journalist      34775.160            3048.930000
# ...           ...  ...         ...            ...                    ...
# 99995  CUS_0xc52a   46      Writer      35032.660            2853.388333
# 99996  CUS_0x83cc   34    Engineer     125047.240           10682.603333
# 99997  CUS_0x6ae6   26      Lawyer       9045.485             644.664842
# 99998  CUS_0x6f0c   20      Lawyer      53564.880            4207.740000
# 99999  CUS_0x743f   28      Lawyer      28901.070            2145.422500
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                      6                4            5.0            3
# 1                      8                3           11.0            4
# 2                      2                4            8.0            0
# 3                      4                6           13.0            3
# 4                      7                9           25.0            5
# ...                  ...              ...            ...          ...
# 99995                 10                6           33.0            7
# 99996                  2                5            9.0            0
# 99997                  8                7           20.0            6
# 99998                  5                3           13.0            2
# 99999                  4                2            9.0            0
#
#        Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# 0                       10                      10                  9.44
# 1                       24                       8                  9.64
# 2                        3                      12                  8.51
# 3                       14                      17                 17.51
# 4                       20                      20                 17.16
# ...                    ...                     ...                   ...
# 99995                   48                      18                  6.52
# 99996                   11                       4                  7.83
# 99997                   52                      16                 19.16
# 99998                    6                       7                 19.98
# 99999                   10                       6                 10.06
#
#        Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# 0                         9   Standard           1396.14
# 1                         2   Standard            268.81
# 2                         0       Good            180.70
# 3                         3   Standard            569.11
# 4                         6        Bad           3003.45
# ...                     ...        ...               ...
# 99995                    10        Bad           1789.00
# 99996                     0       Good           1223.02
# 99997                    11        Bad           2271.24
# 99998                     2   Standard           1008.31
# 99999                     2       Good            996.22
#
#        Credit_Utilization_Ratio  Credit_History_Age Payment_of_Min_Amount  \
# 0                     33.061861                 156                   Yes
# 1                     36.377621                 269                   Yes
# 2                     39.917508                 326                    No
# 3                     39.841494                 376                   Yes
# 4                     36.058472                 162                   Yes
# ...                         ...                 ...                   ...
# 99995                 25.463506                 135                   Yes
# 99996                 33.415357                 325                    No
# 99997                 36.752789                 224                   Yes
# 99998                 28.206586                 190                   Yes
# 99999                 30.150100                 257                    No
#
#        Total_EMI_per_month  Amount_invested_monthly  \
# 0                52.138474                44.084010
# 1                51.934634                39.628311
# 2                 0.000000                84.774645
# 3                16.941903                41.943603
# 4               126.596814                67.970377
# ...                    ...                      ...
# 99995           150.500097               106.840174
# 99996             0.000000               228.184209
# 99997            63.795418                24.218367
# 99998            80.569833               215.490636
# 99999             0.000000                53.345698
#
#                       Payment_Behaviour  Monthly_Balance Last_Loan_9  \
# 0      High_spent_Medium_value_payments       321.019683     No Loan
# 1        Low_spent_Small_value_payments       327.009597     No Loan
# 2       High_spent_Small_value_payments       432.727105     No Loan
# 3       Low_spent_Medium_value_payments       346.630494     No Loan
# 4      High_spent_Medium_value_payments       360.325808     No Loan
# ...                                 ...              ...         ...
# 99995   High_spent_Small_value_payments       287.998562     No Loan
# 99996   High_spent_Large_value_payments      1080.076124     No Loan
# 99997    Low_spent_Small_value_payments       285.190831     No Loan
# 99998   High_spent_Small_value_payments       384.713531     No Loan
# 99999  High_spent_Medium_value_payments       401.196552     No Loan
#
#       Last_Loan_8          Last_Loan_7    Last_Loan_6    Last_Loan_5  \
# 0         No Loan              No Loan        No Loan        No Loan
# 1         No Loan              No Loan        No Loan        No Loan
# 2         No Loan              No Loan        No Loan        No Loan
# 3         No Loan              No Loan        No Loan        No Loan
# 4         No Loan              No Loan        No Loan      Auto Loan
# ...           ...                  ...            ...            ...
# 99995     No Loan  Credit-Builder Loan   Student Loan  Personal Loan
# 99996     No Loan              No Loan        No Loan        No Loan
# 99997     No Loan              No Loan  Not Specified   Student Loan
# 99998     No Loan              No Loan        No Loan        No Loan
# 99999     No Loan              No Loan        No Loan        No Loan
#
#                    Last_Loan_4              Last_Loan_3       Last_Loan_2  \
# 0                      No Loan  Debt Consolidation Loan  Home Equity Loan
# 1      Debt Consolidation Loan         Home Equity Loan         Auto Loan
# 2                      No Loan                  No Loan           No Loan
# 3                      No Loan            Personal Loan      Student Loan
# 4                Mortgage Loan                Auto Loan       Payday Loan
# ...                        ...                      ...               ...
# 99995            Mortgage Loan              Payday Loan       Payday Loan
# 99996                  No Loan                  No Loan           No Loan
# 99997                Auto Loan            Not Specified      Student Loan
# 99998                  No Loan                  No Loan     Mortgage Loan
# 99999                  No Loan                  No Loan           No Loan
#
#                    Last_Loan_1 Credit_Score
# 0      Debt Consolidation Loan     Standard
# 1                    Auto Loan     Standard
# 2                      No Loan         Good
# 3             Home Equity Loan     Standard
# 4                Not Specified         Poor
# ...                        ...          ...
# 99995             Student Loan         Poor
# 99996                  No Loan     Standard
# 99997                Auto Loan         Poor
# 99998            Personal Loan     Standard
# 99999                  No Loan         Good
#
# [100000 rows x 32 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Customer_ID               100000 non-null  object
#  1   Age                       100000 non-null  int64
#  2   Occupation                100000 non-null  object
#  3   Annual_Income             100000 non-null  float64
#  4   Monthly_Inhand_Salary     100000 non-null  float64
#  5   Num_Bank_Accounts         100000 non-null  int64
#  6   Num_Credit_Card           100000 non-null  int64
#  7   Interest_Rate             100000 non-null  float64
#  8   Num_of_Loan               100000 non-null  int64
#  9   Delay_from_due_date       100000 non-null  int64
#  10  Num_of_Delayed_Payment    100000 non-null  int64
#  11  Changed_Credit_Limit      100000 non-null  float64
#  12  Num_Credit_Inquiries      100000 non-null  int64
#  13  Credit_Mix                100000 non-null  object
#  14  Outstanding_Debt          100000 non-null  float64
#  15  Credit_Utilization_Ratio  100000 non-null  float64
#  16  Credit_History_Age        100000 non-null  int64
#  17  Payment_of_Min_Amount     100000 non-null  object
#  18  Total_EMI_per_month       100000 non-null  float64
#  19  Amount_invested_monthly   100000 non-null  float64
#  20  Payment_Behaviour         100000 non-null  object
#  21  Monthly_Balance           100000 non-null  float64
#  22  Last_Loan_9               100000 non-null  object
#  23  Last_Loan_8               100000 non-null  object
#  24  Last_Loan_7               100000 non-null  object
#  25  Last_Loan_6               100000 non-null  object
#  26  Last_Loan_5               100000 non-null  object
#  27  Last_Loan_4               100000 non-null  object
#  28  Last_Loan_3               100000 non-null  object
#  29  Last_Loan_2               100000 non-null  object
#  30  Last_Loan_1               100000 non-null  object
#  31  Credit_Score              100000 non-null  object
# dtypes: float64(9), int64(8), object(15)
# memory usage: 24.4+ MB

# %% [markdown]
# # **GIẢI THÍCH DỮ LIỆU:**

# %% [markdown]
# **ID:** Mã định danh duy nhất cho mỗi bản ghi trong bộ dữ liệu.
#
# **Customer_ID:** Mã định danh duy nhất cho từng khách hàng.
#
# **Month:** Tháng ghi nhận dữ liệu liên quan đến khách hàng
#
# **Name:** Tên của khách hàng.
#
# **Age:** Tuổi của khách hàng.
#
# **SSN (Social Security Number):** Số an sinh xã hội, một mã duy nhất được cấp cho mỗi công dân (chủ yếu ở Hoa Kỳ) nhằm theo dõi các quyền lợi và thuế.
#
# **Occupation:** Nghề nghiệp của khách hàng.
#
# **Annual_Income:** Thu nhập hàng năm của khách hàng.
#
# **Monthly_Inhand_Salary:** Mức lương hàng tháng mà khách hàng nhận được sau khi đã trừ các khoản thuế và chi phí.
#
# **Num_Bank_Accounts:** Số lượng tài khoản ngân hàng mà khách hàng hiện có.
#
# **Num_Credit_Card:** Số lượng thẻ tín dụng mà khách hàng sở hữu.
#
# **Interest_Rate:** Lãi suất áp dụng cho khách hàng liên quan đến các khoản vay hoặc thẻ tín dụng.
#
# **Num_of_Loan:** Số lượng khoản vay mà khách hàng đang có.
#
# **Type_of_Loan:** Loại hình vay mà khách hàng đang tham gia (ví dụ: vay mua nhà, vay xe hơi, vay tiêu dùng).
#
# **Delay_from_due_date:** Số ngày khách hàng trễ hạn thanh toán so với ngày đến hạn.
#
# **Num_of_Delayed_Payment:** Số lần khách hàng đã thanh toán chậm so với kỳ hạn thanh toán.
#
# **Changed_Credit_Limit:** Thay đổi trong giới hạn tín dụng của khách hàng (nếu có), thể hiện mức thay đổi tín dụng được cấp.
#
# **Num_Credit_Inquiries:** Số lần khách hàng đã yêu cầu kiểm tra tín dụng (thường liên quan đến việc xin vay hoặc mở thẻ tín dụng).
#
# **Credit_Mix:** Sự kết hợp giữa các loại sản phẩm tín dụng mà khách hàng có, chẳng hạn như thẻ tín dụng, khoản vay cá nhân, khoản vay thế chấp...
#
# **Outstanding_Debt:** Số dư nợ còn lại mà khách hàng chưa thanh toán.
#
# **Credit_Utilization_Ratio:** Tỷ lệ sử dụng tín dụng, cho biết phần trăm tín dụng khách hàng đang sử dụng so với giới hạn tín dụng được cấp.
#
# **Credit_History_Age:** Độ tuổi của lịch sử tín dụng của khách hàng, tức là thời gian khách hàng đã sử dụng tín dụng.
#
# **Payment_of_Min_Amount:** Thông tin về việc khách hàng có thanh toán tối thiểu của hóa đơn tín dụng hay không (có hoặc không).
#
# **Total_EMI_per_month:** Tổng số tiền phải thanh toán hàng tháng cho các khoản vay (EMI: Equated Monthly Installment).
#
# **Amount_invested_monthly:** Số tiền mà khách hàng đầu tư hàng tháng (có thể liên quan đến các khoản tiết kiệm hoặc đầu tư).
#
# **Payment_Behaviour:** Hành vi thanh toán của khách hàng, thể hiện mức độ đều đặn và chính xác của các khoản thanh toán (có thể là định tính hoặc định lượng).
#
# **Monthly_Balance:** Số dư tài chính hàng tháng của khách hàng sau khi đã trừ đi các chi phí và khoản thanh toán.
#
# **Credit_Score:** Điểm tín dụng của khách hàng, một chỉ số quan trọng để đánh giá khả năng tín dụng và rủi ro tài chính.

# %% [markdown]
# # **II.CHECKING**

# %%
category_cols = ['Occupation', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Num_of_Loan', 'Num_Credit_Inquiries', 
                 'Credit_Mix', 'Payment_of_Min_Amount', 'Payment_Behaviour', 'Last_Loan_9', 'Last_Loan_8', 'Last_Loan_7', 
                 'Last_Loan_6', 'Last_Loan_5', 'Last_Loan_4', 'Last_Loan_3', 'Last_Loan_2', 'Last_Loan_1']

numeric_cols = ['Age', 'Annual_Income', 'Monthly_Inhand_Salary', 'Interest_Rate', 'Delay_from_due_date', 
                'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Outstanding_Debt', 'Credit_Utilization_Ratio', 
                'Credit_History_Age', 'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance']

# %%
data[numeric_cols].describe()
# Out:
#                  Age  Annual_Income  Monthly_Inhand_Salary  Interest_Rate  \
# count  100000.000000  100000.000000          100000.000000   100000.00000
# mean       33.309240   50505.123449            4198.771859       14.53208
# std        10.764996   38299.422093            3187.494345        8.74133
# min        14.000000    7005.930000             303.645417        1.00000
# 25%        24.000000   19342.972500            1626.761667        7.00000
# 50%        33.000000   36999.705000            3096.378333       13.00000
# 75%        42.000000   71683.470000            5961.745000       20.00000
# max        56.000000  179987.280000           15204.633333       34.00000
#
#        Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# count        100000.000000           100000.000000         100000.000000
# mean             21.068780               13.329240             10.389098
# std              14.860104                6.269066              6.783550
# min              -5.000000                0.000000             -6.490000
# 25%              10.000000                9.000000              5.340000
# 50%              18.000000               14.000000              9.400000
# 75%              28.000000               18.000000             14.850000
# max              67.000000               28.000000             36.970000
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# count     100000.000000             100000.000000       100000.000000
# mean        1426.220376                 32.285173          221.206880
# std         1155.129026                  5.116875           99.681112
# min            0.230000                 20.000000            1.000000
# 25%          566.072500                 28.052567          144.000000
# 50%         1166.155000                 32.305784          219.000000
# 75%         1945.962500                 36.496663          302.000000
# max         4998.070000                 50.000000          404.000000
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance
# count        100000.000000            100000.000000    100000.000000
# mean             88.209450               193.686347       403.492393
# std              83.244703               194.785222       214.423009
# min              -1.000000                 0.000000         0.007760
# 25%              25.589532                73.730625       270.322511
# 50%              61.541296               129.361839       337.270985
# 75%             131.528154               234.346249       471.928804
# max             357.406068              1977.326102      1602.040519

# %% [markdown]
# ***Như vậy, dữ liệu nhìn chung không có giá trị outliers, duy chỉ có "Total_EMI_per_month" không nên <0, nên ta sẽ bỏ đi***

# %%
data = data[data['Total_EMI_per_month']>=0]

# %%
df_good = data[data['Credit_Score']=='Good']
df_stand = data[data['Credit_Score']=='Standard']
df_poor = data[data['Credit_Score']=='Poor']

# %% [markdown]
# # **EDA**

# %%
for data_frame in [df_good, df_stand, df_poor]:
    plt.figure(figsize=(8, 5))
    sns.scatterplot(x='Annual_Income', y='Monthly_Inhand_Salary', data=data_frame)
    plt.title('Scatter Plot of Annual_Income vs Monthly_Inhand_Salary')
    plt.xlabel('Annual_Income')
    plt.ylabel('Monthly_Inhand_Salary')
    plt.show()

# %%
for i in numeric_cols:
    plt.figure(figsize=(8, 5))
    sns.violinplot(x='Credit_Score', y=i, data=data, split=True, hue='Credit_Score', palette=['teal', 'skyblue', 'salmon'])
    plt.title(f'Violin Plot of {i} by target Credit_Score')
    plt.xlabel('Credit_Score')
    plt.ylabel(f'Value of {i}')
    plt.legend(title='Credit_Score', loc='upper right')
    plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ***Nhận xét: Nhìn qua bản đồ, dễ thấy các columns có thể có ảnh hưởng mạnh mẽ bao gồm: Credit_History_Age, Outstanding_Debt, Num_Of_Delayed_Payment, Delay_from_Due_date, Interested_rate, Monthly_inhance_salary, Annual_income***

# %% [markdown]
# # **FUNCTION**

# %%
#Hàm đánh giá hiệu suất
def print_scores(y_test, y_pred):
  print(classification_report(y_test, y_pred))

#Hàm chia tập train-test và MinMax Scaler
def preprocess_data(data, test_size=0.3, random_state=42):

    # Chia tập train-test
    X = data.drop(columns=['BAD'], axis=1)
    y = data['BAD']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    #Standard Scaler:
    scaler = MinMaxScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    return X_train, X_test, y_train, y_test

# Hàm tính Cross Validation
def cross_val(model, X_train, y_train):
    cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')
    print("Cross-validation scores:", cv_scores)
    print("Mean CV score:", cv_scores.mean())
    print("Standard deviation of CV score:", cv_scores.std())
    return cv_scores, cv_scores.mean(), cv_scores.std()

#Hàm tính Gini
def gini_coefficient(y_true, y_pred):
    # Tính chỉ số Gini từ AUC
    auc = roc_auc_score(y_true, y_pred)
    return 2 * auc - 1

# Hàm tính chỉ số KS
def ks_statistic(y_true, y_pred_prob):
    # Tính các giá trị ROC
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    # Tính KS = max(TPR - FPR)
    ks_stat = max(tpr - fpr)
    return ks_stat

# %%
#Hàm xử lý các cột bị lệch bằng phép biến đổi logarit, đưa chúng về các giá trị ít lệch hơn
def transform_skewed_features(data, skewed_features):
  for col in skewed_features:
    data[col] = np.log1p(data[col])
  return data

#standard Scaler chuẩn hóa các cột có phân phối bình thường
def transform_non_skewed_features(data, non_skewed_features):
  standardScaler = StandardScaler()
  for col in non_skewed_features:
    data[col] = standardScaler.fit_transform(data[[col]])
  return data

# %%
#Hàm train, test
def train_test_model(model, X_train, y_train, X_test, y_test):
    print(f"Model:", model)
    model.fit(X_train, y_train)
    
    # Dự đoán cho tập huấn luyện và tập kiểm tra
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Tính xác suất dự đoán và hệ số Gini cho tập huấn luyện
    y_train_pred_prob = model.predict_proba(X_train)[:, 1]
    gini_train = gini_coefficient(y_train, y_train_pred_prob)

    # Tính xác suất dự đoán và hệ số Gini cho tập kiểm tra
    y_test_pred_prob = model.predict_proba(X_test)[:, 1]
    gini_test = gini_coefficient(y_test, y_test_pred_prob)

    # In các chỉ số đánh giá cho tập huấn luyện
    print_scores(y_train, y_train_pred)
    print("Gini train:", gini_train)

    # In các chỉ số đánh giá cho tập kiểm tra
    print_scores(y_test, y_test_pred)
    print("Gini test:", gini_test)

    # Thực hiện đánh giá chéo (cross-validation)
    cv_scores, cv_mean, cv_std = cross_val(model, X_train, y_train)

# %%
#Hàm Stacking 2 models
def stacking_models(model_1, model_2, X_train, y_train, X_test, y_test):
    model_1.fit(X_train, y_train)

    # Tạo dự đoán cho tập huấn luyện và tập kiểm tra
    y_train_pred_1 = model_1.predict_proba(X_train)[:, 1]
    y_test_pred_1 = model_1.predict_proba(X_test)[:, 1]

    # Chuyển đổi dự đoán của mô hình Random Forest thành ma trận
    train_meta_features = y_train_pred_1.reshape(-1, 1)  
    test_meta_features = y_test_pred_1.reshape(-1, 1)  

    # Tạo và huấn luyện mô hình Logistic Regression
    model_2.fit(train_meta_features, y_train)

    # Dự đoán với mô hình meta trên tập kiểm tra
    y_train_pred_2 = model_2.predict(train_meta_features)
    y_test_pred_2 = model_2.predict(test_meta_features)

    # Tính xác suất dự đoán và hệ số Gini cho tập kiểm tra
    y_train_pred_prob_2 = model_2.predict_proba(train_meta_features)[:, 1]
    y_test_pred_prob_2 = model_2.predict_proba(test_meta_features)[:, 1]

    #Chỉ số Gini
    gini_train = gini_coefficient(y_train, y_train_pred_prob_2)
    gini_test = gini_coefficient(y_test, y_test_pred_prob_2)

    print_scores(y_train, y_train_pred_2)
    print("Gini train:", gini_train)
    print_scores(y_test, y_test_pred_2)
    print("Gini test:", gini_test)

    cv_scores, cv_mean, cv_std = cross_val(model_2, train_meta_features, y_train)

# %%
def calculate_odds_bad_rate(data, feature, target):
    # Tính tổng số trường hợp và tổng số "bad" cho mỗi giá trị của feature
    feature_group = data.groupby(feature)[target].agg(['sum', 'count'])
    feature_group.columns = ['bad', 'total']
    # Tính số trường hợp "good"
    feature_group['good'] = feature_group['total'] - feature_group['bad']
    # Tính tỷ lệ bad và good
    feature_group['bad_rate'] = feature_group['bad'] / feature_group['total']
    feature_group['good_rate'] = feature_group['good'] / feature_group['total']
    # Tính Odds
    feature_group['odds'] = feature_group['good'] / feature_group['bad']
    # Tính tổng số trường hợp "good" và "bad" để tính WOE và IV
    total_good = feature_group['good'].sum()
    total_bad = feature_group['bad'].sum()
    # Tính WOE và IV
    feature_group['WOE'] = np.log((feature_group['good'] / total_good) / (feature_group['bad'] / total_bad))
    feature_group['IV'] = (feature_group['good'] / total_good - feature_group['bad'] / total_bad) * feature_group['WOE']
    # Xử lý các giá trị vô hạn hoặc lỗi chia 0 (do log hoặc chia cho 0)
    feature_group.replace([np.inf, -np.inf], np.nan, inplace=True)
    feature_group.fillna(0, inplace=True)
    
    # Tính tổng IV cho tất cả các nhóm
    total_iv = feature_group['IV'].sum()
    print(f"Total IV for {feature}: {total_iv:.4f}")
    
    return feature_group[['good', 'bad', 'good_rate', 'bad_rate', 'odds', 'WOE', 'IV']]

# %% [markdown]
# # **FEATURES SELECTIONS**

# %% [markdown]
# ***Kiểm định Chi-squared cho các biến Phân loại***

# %%
remove_obj_cols =[]
#Chi-square test cho các cột Object so với cột Output của data
for i in category_cols:
  chi2, pval, _, _ = chi2_contingency(pd.crosstab(data[i], data['Credit_Score']))
  print(i, '---', pval)
  if pval > 0.05:
    remove_obj_cols.append(i)
  else:
    continue
print(remove_obj_cols)
# Out:
# Occupation --- 2.6511232774374146e-24
# Num_Bank_Accounts --- 0.0
# Num_Credit_Card --- 0.0
# Num_of_Loan --- 0.0
# Num_Credit_Inquiries --- 0.0
# Credit_Mix --- 0.0
# Payment_of_Min_Amount --- 0.0
# Payment_Behaviour --- 0.0
# Last_Loan_9 --- 6.071595175793e-311
# Last_Loan_8 --- 0.0
# Last_Loan_7 --- 0.0
# Last_Loan_6 --- 0.0
# Last_Loan_5 --- 0.0
# Last_Loan_4 --- 0.0
# Last_Loan_3 --- 0.0
# Last_Loan_2 --- 0.0
# Last_Loan_1 --- 0.0
# []

# %% [markdown]
# ***WOE cho các biến phân loại***

# %%
data_cp = data.copy()
data_cp['BAD'] = data_cp['Credit_Score'].apply(lambda x: 1 if x == 'Poor' else 0)

# %%
for i in category_cols:
    result = calculate_odds_bad_rate(data_cp, i, 'BAD')
    print(f'Odds và Bad Rate cho feature "{i}":')
    print(result)
    print("\n")
    print('------------------------------------------------------------')
# Out:
# Total IV for Occupation: 0.0048
# Odds và Bad Rate cho feature "Occupation":
#                good   bad  good_rate  bad_rate      odds       WOE        IV
# Occupation
# Accountant     4706  2036   0.698012  0.301988  2.311395 -0.057729  0.000227
# Architect      4966  1852   0.728366  0.271634  2.681425  0.090768  0.000551
# Developer      4796  1924   0.713690  0.286310  2.492723  0.017796  0.000021
# Doctor         4763  1804   0.725293  0.274707  2.640244  0.075291  0.000366
# Engineer       4770  2094   0.694930  0.305070  2.277937 -0.072310  0.000364
# Entrepreneur   4610  2033   0.693964  0.306036  2.267585 -0.076865  0.000399
# Journalist     4692  1840   0.718310  0.281690  2.550000  0.040513  0.000106
# Lawyer         5131  1965   0.723083  0.276917  2.611196  0.064228  0.000289
# Manager        4576  1856   0.711443  0.288557  2.465517  0.006821  0.000003
# Mechanic       4732  2042   0.698553  0.301447  2.317336 -0.055162  0.000209
# Media_Manager  4956  1764   0.737500  0.262500  2.809524  0.137435  0.001232
# Musician       4565  1783   0.719124  0.280876  2.560292  0.044541  0.000125
# Scientist      4682  2062   0.694247  0.305753  2.270611 -0.075531  0.000391
# Teacher        4645  2027   0.696193  0.303807  2.291564 -0.066346  0.000298
# Writer         4397  1907   0.697494  0.302506  2.305716 -0.060189  0.000231
#
#
# ------------------------------------------------------------
# Total IV for Num_Bank_Accounts: 0.5342
# Odds và Bad Rate cho feature "Num_Bank_Accounts":
#                     good   bad  good_rate  bad_rate      odds       WOE  \
# Num_Bank_Accounts
# 0                   3628   788   0.821558  0.178442  4.604061  0.631358
# 1                   3821   713   0.842744  0.157256  5.359046  0.783206
# 2                   3699   641   0.852304  0.147696  5.770671  0.857208
# 3                  10213  1892   0.843701  0.156299  5.397992  0.790447
# 4                  10393  1949   0.842084  0.157916  5.332478  0.778236
# 5                  10295  2002   0.837196  0.162804  5.142358  0.741931
# 6                   8447  4727   0.641187  0.358813  1.786968 -0.315060
# 7                   8147  4847   0.626982  0.373018  1.680834 -0.376291
# 8                   8229  4714   0.635788  0.364212  1.745651 -0.338453
# 9                   2036  3465   0.370115  0.629885  0.587590 -1.427306
# 10                  2076  3245   0.390152  0.609848  0.639753 -1.342253
# 11                     3     6   0.333333  0.666667  0.500000 -1.588727
#
#                          IV
# Num_Bank_Accounts
# 0                  0.015105
# 1                  0.022894
# 2                  0.025713
# 3                  0.062133
# 4                  0.061617
# 5                  0.056361
# 6                  0.013884
# 7                  0.019730
# 8                  0.015803
# 9                  0.129666
# 10                 0.110997
# 11                 0.000262
#
#
# ------------------------------------------------------------
# Total IV for Num_Credit_Card: 0.8483
# Odds và Bad Rate cho feature "Num_Credit_Card":
#                   good   bad  good_rate  bad_rate         odds       WOE  \
# Num_Credit_Card
# 0                   14     0   1.000000  0.000000     0.000000  0.000000
# 1                 2183     2   0.999085  0.000915  1091.500000  6.099728
# 2                 2179    14   0.993616  0.006384   155.642857  4.151984
# 3                11678  1882   0.861209  0.138791     6.205101  0.929791
# 4                12339  2017   0.859501  0.140499     6.117501  0.915573
# 5                13569  5335   0.717785  0.282215     2.543393  0.037919
# 6                11796  5131   0.696875  0.303125     2.298967 -0.063120
# 7                11713  5307   0.688190  0.311810     2.207085 -0.103908
# 8                 1885  3187   0.371648  0.628352     0.591465 -1.420733
# 9                 1778  2971   0.374395  0.625605     0.598452 -1.408990
# 10                1839  3121   0.370766  0.629234     0.589234 -1.424512
# 11                  14    22   0.388889  0.611111     0.636364 -1.347565
#
#                        IV
# Num_Credit_Card
# 0                0.000000
# 1                0.187159
# 2                0.125443
# 3                0.092596
# 4                0.095442
# 5                0.000270
# 6                0.000683
# 7                0.001877
# 8                0.118466
# 9                0.109113
# 10               0.116461
# 11               0.000757
#
#
# ------------------------------------------------------------
# Total IV for Num_of_Loan: 0.6180
# Odds và Bad Rate cho feature "Num_of_Loan":
#               good   bad  good_rate  bad_rate      odds       WOE        IV
# Num_of_Loan
# 0            10072  1336   0.882889  0.117111  7.538922  1.124499  0.107726
# 1             9895  1233   0.889198  0.110802  8.025142  1.186999  0.114971
# 2            11955  3757   0.760883  0.239117  3.182060  0.261949  0.010166
# 3            12315  3437   0.781805  0.218195  3.583067  0.380639  0.020905
# 4            12163  3283   0.787453  0.212547  3.704843  0.414061  0.024053
# 5             3634  3891   0.482924  0.517076  0.933950 -0.963913  0.080034
# 6             4012  4132   0.492633  0.507367  0.970958 -0.925052  0.079572
# 7             3654  4025   0.475843  0.524157  0.907826 -0.992283  0.086697
# 8             1498  1833   0.449715  0.550285  0.817239 -1.097403  0.046232
# 9             1789  2062   0.464555  0.535445  0.867604 -1.037600  0.047656
#
#
# ------------------------------------------------------------
# Total IV for Num_Credit_Inquiries: 0.8955
# Odds và Bad Rate cho feature "Num_Credit_Inquiries":
#                        good   bad  good_rate  bad_rate      odds       WOE  \
# Num_Credit_Inquiries
# 0                      6496   777   0.893167  0.106833  8.360360  1.227921
# 1                      6894   987   0.874762  0.125238  6.984802  1.048156
# 2                      7287  1100   0.868845  0.131155  6.624545  0.995201
# 3                      8132  1056   0.885067  0.114933  7.700758  1.145738
# 4                     10405  1338   0.886060  0.113940  7.776532  1.155530
# 5                      5014   872   0.851852  0.148148  5.750000  0.853620
# 6                      5671  2705   0.677053  0.322947  2.096488 -0.155317
# 7                      5477  2883   0.655144  0.344856  1.899757 -0.253854
# 8                      5173  2957   0.636285  0.363715  1.749408 -0.336303
# 9                      2608  2863   0.476695  0.523305  0.910933 -0.988867
# 10                     2279  2834   0.445727  0.554273  0.804164 -1.113533
# 11                     2090  3148   0.399007  0.600993  0.663914 -1.305184
# 12                     1799  2930   0.380419  0.619581  0.613993 -1.383352
# 13                      652   870   0.428384  0.571616  0.749425 -1.184029
# 14                      414   664   0.384045  0.615955  0.623494 -1.367996
# 15                      315   521   0.376794  0.623206  0.604607 -1.398758
# 16                      176   295   0.373673  0.626327  0.596610 -1.412072
# 17                      105   189   0.357143  0.642857  0.555556 -1.483367
#
#                             IV
# Num_Credit_Inquiries
# 0                     0.079454
# 1                     0.066106
# 2                     0.064397
# 3                     0.089515
# 4                     0.116039
# 5                     0.034616
# 6                     0.002085
# 7                     0.005660
# 8                     0.009797
# 9                     0.061332
# 10                    0.073111
# 11                    0.103306
# 12                    0.104761
# 13                    0.024659
# 14                    0.023356
# 15                    0.018932
# 16                    0.010869
# 17                    0.007477
#
#
# ------------------------------------------------------------
# Total IV for Credit_Mix: 0.6826
# Odds và Bad Rate cho feature "Credit_Mix":
#              good    bad  good_rate  bad_rate      odds       WOE        IV
# Credit_Mix
# Bad          9477  14281   0.398897  0.601103  0.663609 -1.305642  0.468898
# Good        25524   4850   0.840324  0.159676  5.262680  0.765060  0.147086
# Standard    35986   9858   0.784966  0.215034  3.650436  0.399266  0.066629
#
#
# ------------------------------------------------------------
# Total IV for Payment_of_Min_Amount: 0.4437
# Odds và Bad Rate cho feature "Payment_of_Min_Amount":
#                         good    bad  good_rate  bad_rate      odds       WOE  \
# Payment_of_Min_Amount
# No                     35120   5438   0.865920  0.134080  6.458257  0.969779
# Yes                    35867  23551   0.603639  0.396361  1.522950 -0.474931
#
#                              IV
# Payment_of_Min_Amount
# No                     0.297868
# Yes                    0.145875
#
#
# ------------------------------------------------------------
# Total IV for Payment_Behaviour: 0.0585
# Odds và Bad Rate cho feature "Payment_Behaviour":
#                                    good    bad  good_rate  bad_rate      odds  \
# Payment_Behaviour
# High_spent_Large_value_payments   12307   3121   0.797705  0.202295  3.943287
# High_spent_Medium_value_payments  15110   5699   0.726128  0.273872  2.651342
# High_spent_Small_value_payments    5994   2258   0.726369  0.273631  2.654562
# Low_spent_Large_value_payments     5433   1920   0.738882  0.261118  2.829687
# Low_spent_Medium_value_payments    8089   3395   0.704371  0.295629  2.382622
# Low_spent_Small_value_payments    24054  12596   0.656317  0.343683  1.909654
#
#                                        WOE        IV
# Payment_Behaviour
# High_spent_Large_value_payments   0.476434  0.031306
# High_spent_Medium_value_payments  0.079486  0.001293
# High_spent_Small_value_payments   0.080699  0.000528
# Low_spent_Large_value_payments    0.144586  0.001490
# Low_spent_Medium_value_payments  -0.027379  0.000087
# Low_spent_Small_value_payments   -0.248658  0.023786
#
#
# ------------------------------------------------------------
# Total IV for Last_Loan_9: 0.0518
# Odds và Bad Rate cho feature "Last_Loan_9":
#                           good    bad  good_rate  bad_rate      odds  \
# Last_Loan_9
# Auto Loan                  230    216   0.515695  0.484305  1.064815
# Credit-Builder Loan        199    233   0.460648  0.539352  0.854077
# Debt Consolidation Loan    168    224   0.428571  0.571429  0.750000
# Home Equity Loan           201    207   0.492647  0.507353  0.971014
# Mortgage Loan              271    249   0.521154  0.478846  1.088353
# No Loan                  69198  26927   0.719875  0.280125  2.569837
# Not Specified              162    262   0.382075  0.617925  0.618321
# Payday Loan                182    279   0.394794  0.605206  0.652330
# Personal Loan              185    199   0.481771  0.518229  0.929648
# Student Loan               191    193   0.497396  0.502604  0.989637
#
#                               WOE        IV
# Last_Loan_9
# Auto Loan               -0.832779  0.003507
# Credit-Builder Loan     -1.053314  0.005513
# Debt Consolidation Loan -1.183262  0.006343
# Home Equity Loan        -0.924994  0.003986
# Mortgage Loan           -0.810914  0.003870
# No Loan                  0.048262  0.002217
# Not Specified           -1.376328  0.009298
# Payday Loan             -1.322785  0.009340
# Personal Loan           -0.968529  0.004125
# Student Loan            -0.905997  0.003594
#
#
# ------------------------------------------------------------
# Total IV for Last_Loan_8: 0.1042
# Odds và Bad Rate cho feature "Last_Loan_8":
#                           good    bad  good_rate  bad_rate      odds  \
# Last_Loan_8
# Auto Loan                  341    379   0.473611  0.526389  0.899736
# Credit-Builder Loan        407    465   0.466743  0.533257  0.875269
# Debt Consolidation Loan    365    395   0.480263  0.519737  0.924051
# Home Equity Loan           413    471   0.467195  0.532805  0.876858
# Mortgage Loan              364    371   0.495238  0.504762  0.981132
# No Loan                  67700  25094   0.729573  0.270427  2.697856
# Not Specified              309    435   0.415323  0.584677  0.710345
# Payday Loan                434    449   0.491506  0.508494  0.966592
# Personal Loan              272    448   0.377778  0.622222  0.607143
# Student Loan               382    482   0.442130  0.557870  0.792531
#
#                               WOE        IV
# Last_Loan_8
# Auto Loan               -1.001234  0.008280
# Credit-Builder Loan     -1.028805  0.010604
# Debt Consolidation Loan -0.974569  0.008268
# Home Equity Loan        -1.026991  0.010711
# Mortgage Loan           -0.914629  0.007015
# No Loan                  0.096877  0.008531
# Not Specified           -1.237585  0.013184
# Payday Loan             -0.929559  0.008714
# Personal Loan           -1.394571  0.016208
# Student Loan            -1.128104  0.012686
#
#
# ------------------------------------------------------------
# Total IV for Last_Loan_7: 0.2192
# Odds và Bad Rate cho feature "Last_Loan_7":
#                           good    bad  good_rate  bad_rate      odds  \
# Last_Loan_7
# Auto Loan                  742    858   0.463750  0.536250  0.864802
# Credit-Builder Loan        793    927   0.461047  0.538953  0.855448
# Debt Consolidation Loan    626    806   0.437151  0.562849  0.776675
# Home Equity Loan           713    815   0.466623  0.533377  0.874847
# Mortgage Loan              827    965   0.461496  0.538504  0.856995
# No Loan                  64046  21069   0.752464  0.247536  3.039822
# Not Specified              797    811   0.495647  0.504353  0.982737
# Payday Loan                949    965   0.495820  0.504180  0.983420
# Personal Loan              790    898   0.468009  0.531991  0.879733
# Student Loan               704    875   0.445852  0.554148  0.804571
#
#                               WOE        IV
# Last_Loan_7
# Auto Loan               -1.040835  0.019927
# Credit-Builder Loan     -1.051711  0.021883
# Debt Consolidation Loan -1.148314  0.021801
# Home Equity Loan        -1.029287  0.018599
# Mortgage Loan           -1.049904  0.022718
# No Loan                  0.216218  0.037931
# Not Specified           -0.912994  0.015291
# Payday Loan             -0.912300  0.018173
# Personal Loan           -1.023717  0.020319
# Student Loan            -1.113026  0.022557
#
#
# ------------------------------------------------------------
# Total IV for Last_Loan_6: 0.3573
# Odds và Bad Rate cho feature "Last_Loan_6":
#                           good    bad  good_rate  bad_rate      odds  \
# Last_Loan_6
# Auto Loan                 1191   1281   0.481796  0.518204  0.929742
# Credit-Builder Loan       1276   1328   0.490015  0.509985  0.960843
# Debt Consolidation Loan   1138   1326   0.461851  0.538149  0.858220
# Home Equity Loan          1124   1336   0.456911  0.543089  0.841317
# Mortgage Loan             1090   1302   0.455686  0.544314  0.837174
# No Loan                  60034  16937   0.779956  0.220044  3.544547
# Not Specified             1313   1310   0.500572  0.499428  1.002290
# Payday Loan               1335   1351   0.497022  0.502978  0.988157
# Personal Loan             1326   1410   0.484649  0.515351  0.940426
# Student Loan              1160   1408   0.451713  0.548287  0.823864
#
#                               WOE        IV
# Last_Loan_6
# Auto Loan               -0.968428  0.026546
# Credit-Builder Loan     -0.935524  0.026041
# Debt Consolidation Loan -1.048475  0.031151
# Home Equity Loan        -1.068367  0.032321
# Mortgage Loan           -1.073304  0.031725
# No Loan                  0.369830  0.096691
# Not Specified           -0.893293  0.023845
# Payday Loan             -0.907494  0.025226
# Personal Loan           -0.957003  0.028671
# Student Loan            -1.089331  0.035108
#
#
# ------------------------------------------------------------
# Total IV for Last_Loan_5: 0.5382
# Odds và Bad Rate cho feature "Last_Loan_5":
#                           good    bad  good_rate  bad_rate      odds  \
# Last_Loan_5
# Auto Loan                 1516   1908   0.442757  0.557243  0.794549
# Credit-Builder Loan       1646   1850   0.470824  0.529176  0.889730
# Debt Consolidation Loan   1732   1796   0.490930  0.509070  0.964365
# Home Equity Loan          1578   1819   0.464528  0.535472  0.867510
# Mortgage Loan             1617   1819   0.470605  0.529395  0.888950
# No Loan                  56400  13046   0.812142  0.187858  4.323164
# Not Specified             1564   1708   0.477995  0.522005  0.915691
# Payday Loan               1585   1755   0.474551  0.525449  0.903134
# Personal Loan             1875   1645   0.532670  0.467330  1.139818
# Student Loan              1474   1643   0.472891  0.527109  0.897139
#
#                               WOE        IV
# Last_Loan_5
# Auto Loan               -1.125561  0.050045
# Credit-Builder Loan     -1.012418  0.041135
# Debt Consolidation Loan -0.931865  0.034997
# Home Equity Loan        -1.037709  0.042046
# Mortgage Loan           -1.013295  0.040500
# No Loan                  0.568407  0.195804
# Not Specified           -0.983657  0.036284
# Payday Loan             -0.997465  0.038115
# Personal Loan           -0.764712  0.023196
# Student Loan            -1.004124  0.036060
#
#
# ------------------------------------------------------------
# Total IV for Last_Loan_4: 0.3409
# Odds và Bad Rate cho feature "Last_Loan_4":
#                           good   bad  good_rate  bad_rate      odds       WOE  \
# Last_Loan_4
# Auto Loan                 2663  2055   0.564434  0.435566  1.295864 -0.636403
# Credit-Builder Loan       3414  2247   0.603074  0.396926  1.519359 -0.477292
# Debt Consolidation Loan   2999  2023   0.597172  0.402828  1.482452 -0.501883
# Home Equity Loan          2935  2264   0.564532  0.435468  1.296378 -0.636006
# Mortgage Loan             3026  2139   0.585866  0.414134  1.414680 -0.548677
# No Loan                  44237  9763   0.819204  0.180796  4.531087  0.615381
# Not Specified             2852  2266   0.557249  0.442751  1.258605 -0.665576
# Payday Loan               3163  2123   0.598373  0.401627  1.489873 -0.496890
# Personal Loan             2911  1944   0.599588  0.400412  1.497428 -0.491831
# Student Loan              2787  2165   0.562803  0.437197  1.287298 -0.643035
#
#                                IV
# Last_Loan_4
# Auto Loan                0.021240
# Credit-Builder Loan      0.014041
# Debt Consolidation Loan  0.013821
# Home Equity Loan         0.023375
# Mortgage Loan            0.017096
# No Loan                  0.176238
# Not Specified            0.025286
# Payday Loan              0.014249
# Personal Loan            0.012813
# Student Loan             0.022778
#
#
# ------------------------------------------------------------
# Total IV for Last_Loan_3: 0.2511
# Odds và Bad Rate cho feature "Last_Loan_3":
#                           good   bad  good_rate  bad_rate      odds       WOE  \
# Last_Loan_3
# Auto Loan                 4453  2354   0.654180  0.345820  1.891674 -0.258118
# Credit-Builder Loan       4677  2639   0.639284  0.360716  1.772262 -0.323323
# Debt Consolidation Loan   4196  2732   0.605658  0.394342  1.535871 -0.466483
# Home Equity Loan          4268  2371   0.642868  0.357132  1.800084 -0.307747
# Mortgage Loan             4363  2507   0.635080  0.364920  1.740327 -0.341507
# No Loan                  31922  6326   0.834606  0.165394  5.046159  0.723047
# Not Specified             4384  2684   0.620260  0.379740  1.633383 -0.404927
# Payday Loan               4191  2577   0.619238  0.380762  1.626310 -0.409267
# Personal Loan             4076  2330   0.636278  0.363722  1.749356 -0.336332
# Student Loan              4457  2469   0.643517  0.356483  1.805184 -0.304918
#
#                                IV
# Last_Loan_3
# Auto Loan                0.004768
# Credit-Builder Loan      0.008131
# Debt Consolidation Loan  0.016389
# Home Equity Loan         0.006668
# Mortgage Loan            0.008544
# No Loan                  0.167362
# Not Specified            0.012484
# Payday Loan              0.012219
# Personal Loan            0.007721
# Student Loan             0.006825
#
#
# ------------------------------------------------------------
# Total IV for Last_Loan_2: 0.2699
# Odds và Bad Rate cho feature "Last_Loan_2":
#                           good   bad  good_rate  bad_rate      odds       WOE  \
# Last_Loan_2
# Auto Loan                 5440  3032   0.642115  0.357885  1.794195 -0.311024
# Credit-Builder Loan       5646  2876   0.662521  0.337479  1.963143 -0.221033
# Debt Consolidation Loan   5437  2833   0.657437  0.342563  1.919167 -0.243689
# Home Equity Loan          5871  2905   0.668984  0.331016  2.020998 -0.191989
# Mortgage Loan             5572  2836   0.662702  0.337298  1.964739 -0.220221
# No Loan                  19967  2569   0.886005  0.113995  7.772285  1.154984
# Not Specified             5844  2882   0.669723  0.330277  2.027759 -0.188649
# Payday Loan               5841  3263   0.641586  0.358414  1.790070 -0.313325
# Personal Loan             5749  2888   0.665625  0.334375  1.990651 -0.207119
# Student Loan              5620  2905   0.659238  0.340762  1.934596 -0.235682
#
#                                IV
# Last_Loan_2
# Auto Loan                0.008695
# Credit-Builder Loan      0.004349
# Debt Consolidation Loan  0.005150
# Home Equity Loan         0.003361
# Mortgage Loan            0.004258
# No Loan                  0.222516
# Not Specified            0.003224
# Payday Loan              0.009487
# Personal Loan            0.003860
# Student Loan             0.004959
#
#
# ------------------------------------------------------------
# Total IV for Last_Loan_1: 0.1193
# Odds và Bad Rate cho feature "Last_Loan_1":
#                           good   bad  good_rate  bad_rate      odds       WOE  \
# Last_Loan_1
# Auto Loan                 6445  2883   0.690931  0.309069  2.235519 -0.091107
# Credit-Builder Loan       6711  3089   0.684796  0.315204  2.172548 -0.119680
# Debt Consolidation Loan   6858  3105   0.688347  0.311653  2.208696 -0.103178
# Home Equity Loan          6841  2956   0.698275  0.301725  2.314276 -0.056483
# Mortgage Loan             6584  3022   0.685405  0.314595  2.178690 -0.116857
# No Loan                  10072  1336   0.882889  0.117111  7.538922  1.124499
# Not Specified             7029  2979   0.702338  0.297662  2.359517 -0.037124
# Payday Loan               6962  3140   0.689170  0.310830  2.217197 -0.099336
# Personal Loan             6699  3237   0.674215  0.325785  2.069509 -0.168269
# Student Loan              6786  3242   0.676705  0.323295  2.093152 -0.156909
#
#                                IV
# Last_Loan_1
# Auto Loan                0.000789
# Credit-Builder Loan      0.001438
# Debt Consolidation Loan  0.001083
# Home Equity Loan         0.000316
# Mortgage Loan            0.001344
# No Loan                  0.107726
# Not Specified            0.000139
# Payday Loan              0.001017
# Personal Loan            0.002910
# Student Loan             0.002548
#
#
# ------------------------------------------------------------

# %%
data = data.drop(columns = ['Occupation', 'Payment_Behaviour', 'Last_Loan_9', 'Last_Loan_8', 'Last_Loan_1'])

# %% [markdown]
# ***Spearman Correlation cho các biến liên tục***

# %%
spear_cols = numeric_cols
spear_cols.append('Credit_Score')
spearman_df = data[spear_cols]
correlation_results = []

# Duyệt qua tất cả các cột trong DataFrame
for col in spearman_df.columns:
  if col == 'Credit_Score':
    continue
  else:
    corr, p_value = spearmanr(spearman_df[col], spearman_df['Credit_Score'])
    correlation_results.append((col, corr, p_value))

# Chuyển kết quả thành DataFrame để dễ quan sát
correlation_df = pd.DataFrame(correlation_results, columns=['Feature', 'Spearman Correlation', 'p-value'])
correlation_df = correlation_df.sort_values(by='Spearman Correlation', ascending=False)
correlation_df
# Out:
#                      Feature  Spearman Correlation        p-value
# 6       Changed_Credit_Limit              0.180814   0.000000e+00
# 5     Num_of_Delayed_Payment              0.141751   0.000000e+00
# 4        Delay_from_due_date              0.084417  1.652905e-157
# 3              Interest_Rate              0.081200  7.570647e-146
# 8   Credit_Utilization_Ratio             -0.007176   2.327227e-02
# 10       Total_EMI_per_month             -0.015723   6.641343e-07
# 12           Monthly_Balance             -0.019357   9.295720e-10
# 11   Amount_invested_monthly             -0.027030   1.251140e-17
# 0                        Age             -0.034090   4.197659e-27
# 2      Monthly_Inhand_Salary             -0.034949   2.102774e-28
# 1              Annual_Income             -0.036477   8.536955e-31
# 7           Outstanding_Debt             -0.044400   8.196105e-45
# 9         Credit_History_Age             -0.046566   4.040465e-49

# %%
data = data.drop(columns = ['Credit_Utilization_Ratio', 'Total_EMI_per_month', 'Monthly_Balance', 'Amount_invested_monthly', 
                            'Age', 'Monthly_Inhand_Salary', 'Annual_Income'])
